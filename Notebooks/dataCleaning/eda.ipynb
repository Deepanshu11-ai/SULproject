# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv("/Users/deepanshus/StockMarketPredictor/Project/data/Combined/all/1.csv")

# %%
df.head()
# Out:
#          rsi      macd  sma_ratio  volume_change  volatility    target
# 0  52.729384  5.231607   1.041503      -0.764616    0.015705 -0.009905
# 1  54.632972  5.343971   1.040495      -0.387146    0.015875  0.033691
# 2  68.850806  6.284495   1.044956       3.874652    0.015084 -0.028466
# 3  57.588533  6.152034   1.046341      -0.729922    0.018880 -0.012892
# 4  53.169572  5.627148   1.046767      -0.136228    0.019619  0.000297

# %%
df['target'].value_counts()
# Out:
# target
#  0.000000    267
# -0.050000      6
# -0.050000      6
#  0.012048      5
#  0.003984      4
#             ...
#  0.014014      1
#  0.020411      1
# -0.000376      1
#  0.003325      1
# -0.011997      1
# Name: count, Length: 51702, dtype: int64

# %%
import matplotlib.pyplot as plt

df['target'].value_counts().plot(kind='bar')
plt.title("Target Distribution (Up vs Down)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 df['target'].value_counts().plot(kind='bar')
#       4 plt.title("Target Distribution (Up vs Down)")
#       5 plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/plotting/_matplotlib/core.py:508, in MPLPlot.generate(self)
#     506 for ax in self.axes:
#     507     self._post_plot_logic_common(ax)
# --> 508     self._post_plot_logic(ax, self.data)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/plotting/_matplotlib/core.py:1975, in BarPlot._post_plot_logic(self, ax, data)
#    1972 s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1973 e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
# -> 1975 self._decorate_ticks(ax, self._get_index_name(), str_index, s_edge, e_edge)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/plotting/_matplotlib/core.py:1990, in BarPlot._decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge)
#    1988     ax.set_xticks(np.array(self.xticks))
#    1989 else:
# -> 1990     ax.set_xticks(self.tick_pos)
#    1991     ax.set_xticklabels(ticklabels)
#    1993 if name is not None and self.use_index:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/matplotlib/axis.py:2218, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2213     first_key = next(iter(kwargs))
#    2214     raise ValueError(
#    2215         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#    2216         "other than 'minor' modify the text labels and can only be used if "
#    2217         "'labels' are passed as well.")
# -> 2218 result = self._set_tick_locations(ticks, minor=minor)
#    2219 if labels is not None:
#    2220     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/matplotlib/axis.py:2170, in Axis._set_tick_locations(self, ticks, minor)
#    2168 else:
#    2169     self.set_major_locator(locator)
# -> 2170     return self.get_major_ticks(len(ticks))
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/matplotlib/axis.py:1666, in Axis.get_major_ticks(self, numticks)
#    1664     tick = self._get_tick(major=True)
#    1665     self.majorTicks.append(tick)
# -> 1666     self._copy_tick_props(self.majorTicks[0], tick)
#    1668 return self.majorTicks[:numticks]
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/matplotlib/axis.py:1610, in Axis._copy_tick_props(self, src, dest)
#    1608 if src is None or dest is None:
#    1609     return
# -> 1610 dest.label1.update_from(src.label1)
#    1611 dest.label2.update_from(src.label2)
#    1612 dest.tick1line.update_from(src.tick1line)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/matplotlib/text.py:349, in Text.update_from(self, other)
#     347 self._verticalalignment = other._verticalalignment
#     348 self._horizontalalignment = other._horizontalalignment
# --> 349 self._fontproperties = other._fontproperties.copy()
#     350 self._usetex = other._usetex
#     351 self._rotation = other._rotation
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/matplotlib/font_manager.py:963, in FontProperties.copy(self)
#     961 def copy(self):
#     962     """Return a copy of self."""
# --> 963     return copy.copy(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/copy.py:90, in copy(x)
#      88 reductor = getattr(x, "__reduce_ex__", None)
#      89 if reductor is not None:
# ---> 90     rv = reductor(4)
#      91 else:
#      92     reductor = getattr(x, "__reduce__", None)
#
# KeyboardInterrupt:

# %%
import seaborn as sns

plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
sns.boxplot(x='target', y='rsi', data=df)
plt.title("RSI vs Movement")
plt.show()

# %%
sns.boxplot(x='target', y='macd', data=df)
plt.title("MACD vs Movement")
plt.show()

# %%
sns.boxplot(x='target', y='sma_ratio', data=df)
plt.title("SMA Ratio vs Movement")
plt.show()

# %%
sns.boxplot(x='target', y='volatility', data=df)
plt.title("Volatility vs Movement")
plt.show()

# %%
sns.boxplot(x='target', y='volume_change', data=df)
plt.title("Volume Change vs Movement")
plt.show()

# %%
df.hist(figsize=(10,8))
plt.show()
